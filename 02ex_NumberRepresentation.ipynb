# %% [markdown]
# 1\. Write a function that converts number representation (bin<->dec<->hex)

# %%
"Exercise 1"

#singular conversion functions
def dec_bin(a):
    l = []

    while a != 0:
        a = int(a)
        q = a%2
        l.append(str(q))
        a /= 2
    l.reverse()
    l.remove('0')
    b = ''.join(l)
    return b

def bin_dec(a):
    l = [int(x) for x in a]
    l.reverse()
    b = 0
    for i in range(len(l)):
        b += l[i]*2**i
    return b

def dec_hex(a):
    l = []
    while a != 0:
        a = int(a)
        q = a%16
        l.append(str(q))
        a /= 16
    l.reverse()
    l.remove('0')
    for i in range(len(l)):
        if l[i] == '10':
            l[i] = 'a'
        elif l[i] == '11':
            l[i] = 'b'
        elif l[i] == '12':
            l[i] = 'c'
        elif l[i] == '13':
            l[i] = 'd'
        elif l[i] == '14':
            l[i] = 'e'
        elif l[i] == '15':
            l[i] = 'f'
    b = ''.join(l)
    return b

def hex_dec(a):
    l = [x for x in a]
    l.reverse()
    for i in range(len(l)):
        if l[i] == 'a':
            l[i] = 10
        elif l[i] == 'b':
            l[i] = 11
        elif l[i] == 'c':
            l[i] = 12
        elif l[i] == 'd':
            l[i] = 13
        elif l[i] == 'e':
            l[i] = 14
        elif l[i] == 'f':
            l[i] = 15
        else:
            l[i] = int(l[i])
    
    b = 0
    for i in range(len(l)):
        b += l[i]*16**i
    
    return b

#generic conversion function
def conversion(string1, string2, n):
    if string1 =='bin' and string2 == 'dec':
        z = bin_dec(n)
    elif string1 =='dec' and string2 == 'bin':
        z = dec_bin(n)
    elif string1 =='hex' and string2 == 'dec':
        z = hex_dec(n)
    elif string1 =='dec' and string2 == 'hex':
        z = dec_hex(n)
    elif string1 =='hex' and string2 == 'bin':
        z = dec_bin(hex_dec(n))
    elif string1 =='bin' and string2 == 'hex':
        z = dec_hex(bin_dec(n))
    return z

print(conversion('bin', 'dec', '10001011'))
print(conversion('dec', 'bin', 139))
print(conversion('hex', 'dec', '8b'))
print(conversion('dec', 'hex', 139))
print(conversion('hex', 'bin', '8b'))
print(conversion('bin', 'hex', '10001011'))

print(conversion('bin', 'dec', '01100000000000000000000'))
# Out:
# 139
# 10001011
# 139
# 8b
# 10001011
# 8b
# 3145728

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
"Exercise 2"

def single_precision_conv(a):
    l = [x for x in a]
    s = l[0]
    e = [x for x in l[1:9]]
    m = [x for x in l[9:32]]

    S = bin_dec(s)
    E = bin_dec(e)
    M = bin_dec(m)

    if E == 0 and M == 0:
        b = 0
    elif S%2 == 0 and E == 255 and M == 0:
        b = 'inf'
    elif S%2 == 0 and E == 255 and M == 0:
        b = 'inf'
    elif E == 255 and M != 0:
        b = 'Nan'
    else:
        M = 1
        for i in range(len(m)):
            if m[i] == '1':
                M += 2**(-(i + 1))

        b = (-1)**S*2**(E - 127)*M

    return b

print(single_precision_conv('11000000101100000000000000000000'))
print(single_precision_conv('00000011111000000000000000000000'))
print(single_precision_conv('11111111100000001010000001010100'))
print(single_precision_conv('01111111100000000000000000000000'))
print(single_precision_conv('00000000000000000000000000000000'))
# Out:
# -5.5
# 1.316553672920962e-36
# Nan
# inf
# 0

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
"Exercise 3"

over, under, i = 1, 1, 0

while True:
    over *= 2
    i += 1
    if i > 10**4:
        break
print('After 10000 iterations the maximum number is:', over)
print('\nPython 3 doesen\'t have an upper limit so surely it can get higher with a longer running but it would take a while before occupying all the memory.')

while True:
    a = under
    under /= 2
    if under == 0:
        break
print('\nThe number closest to 0 is:', a)
# Out:
# After 10000 iterations the maximum number is: ...
#
# Python 3 doesen't have an upper limit so surely it can get higher with a longer running but it would take a while before occupying all the memory.
#
# The number closest to 0 is: 5e-324

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
'Exercise 4'

b, i = 0, 0

while True:
    a = b
    i +=1
    b = a + 10**(-i)
    if b == a:
        break
print(b)
print('The precision of this machine is:', 10**(-i))
# Out:
# 0.11111111111111112
# The precision of this machine is: 1e-18

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
"Exercise 5"

#a)
print('a)')

def second_deg_eq_1(a,b,c):
    x1 = (-b + (b**2 - 4*a*c)**(1/2))/(2*a)
    x2 = (-b - (b**2 - 4*a*c)**(1/2))/(2*a)
    return x1, x2

print(second_deg_eq_1(0.001,1000,0.001))

#b)
print('b)')

def second_deg_eq_2(a,b,c):
    x1 = (4*a*c)/(2*a*(-b - (b**2 - 4*a*c)**(1/2)))
    x2 = (4*a*c)/(2*a*(-b + (b**2 - 4*a*c)**(1/2)))
    return x1, x2

print(second_deg_eq_2(0.001,1000,0.001))
print('This results are different from the latter.')
print('This happens because changing the order of operations also changes the result')

#c)
print('c)')

print('The problem is in the operation \'-b + (b**2 - 4*a*c)**(1/2)\' because for b >> 1 and a*c << 1 we can approximate it with \'-b + b\' which gives 0.')
print('To solve that problem we can factorize the square root only on the +_solution and use the common formula for the -_solution.')

def second_deg_eq(a,b,c):
    x1 = (4*a*c)/(2*a*(-b - (b**2 - 4*a*c)**(1/2)))
    x2 = (-b - (b**2 - 4*a*c)**(1/2))/(2*a)
    return x1, x2

print(second_deg_eq(0.001,1000,0.001))
# Out:
# a)
# (-9.999894245993346e-07, -999999.999999)
# b)
# (-1.0000000000009999e-06, -1000010.5755125057)
# This results are different from the latter.
# This happens because changing the order of operations also changes the result
# c)
# The problem is in the operation '-b + (b**2 - 4*a*c)**(1/2)' because for b >> 1 and a*c << 1 we can approximate it with '-b + b' which gives 0.
# To solve that problem we can factorize the square root only on the +_solution and use the common formula for the -_solution.
# (-1.0000000000009999e-06, -999999.999999)

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
'Exercise 6'

df_true = 1

#a)
d = 10**(-2)
x = 1
f = x*(x - 1)
F = (x + d)*(x + d - 1)
df = (F - f)/d
print(df)
print('accuracy:', abs(df - df_true)/df_true*100)

#b)
d = 10**(-4)
x = 1
f = x*(x - 1)
F = (x + d)*(x + d - 1)
df = (F - f)/d
print(df)
print('accuracy:', abs(df - df_true)/df_true*100)

d = 10**(-6)
x = 1
f = x*(x - 1)
F = (x + d)*(x + d - 1)
df = (F - f)/d
print(df)
print('accuracy:', abs(df - df_true)/df_true*100)

d = 10**(-8)
x = 1
f = x*(x - 1)
F = (x + d)*(x + d - 1)
df = (F - f)/d
print(df)
print('accuracy:', abs(df - df_true)/df_true*100)

d = 10**(-10)
x = 1
f = x*(x - 1)
F = (x + d)*(x + d - 1)
df = (F - f)/d
print(df)
print('accuracy:', abs(df - df_true)/df_true*100)

d = 10**(-12)
x = 1
f = x*(x - 1)
F = (x + d)*(x + d - 1)
df = (F - f)/d
print(df)
print('accuracy:', abs(df - df_true)/df_true*100)

d = 10**(-14)
x = 1
f = x*(x - 1)
F = (x + d)*(x + d - 1)
df = (F - f)/d
print(df)
print('accuracy:', abs(df - df_true)/df_true*100)
# Out:
# 1.010000000000001
# accuracy: 1.0000000000000897
# 1.0000999999998899
# accuracy: 0.009999999988985486
# 1.0000009999177333
# accuracy: 9.99917733279787e-05
# 1.0000000039225287
# accuracy: 3.9225287462585356e-07
# 1.000000082840371
# accuracy: 8.284037100736441e-06
# 1.0000889005833413
# accuracy: 0.008890058334132256
# 0.9992007221626509
# accuracy: 0.07992778373491216

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
'Exercise 7'
import math
true_val = math.pi/2

#a)
print('a)')

y = lambda x: math.sqrt(1 - x**2)

def integral(N):
    I = 0
    h = 2/N
    x = [-1 + i*h for i in range(0,N)]
    for i in range(N):
        I += h*y(x[i])
    return I

I = integral(100)
print('I =', I)
print('accuracy = ', abs((I - true_val)/true_val*100))


#b)
print('b)')

import time
t0 = time.time()

N = 100
while True:
    N *= 2
    I = integral(N)
    if time.time() - t0 > 1:
        break

print('N =', N)
print('I =', I)
print('accuracy = ', abs((I - true_val)/true_val*100))

t0 = time.time()

N = 100
while True:
    N *= 2
    I = integral(N)
    if time.time() - t0 > 60:
        break

print('N =', N)
print('I =', I)
print('accuracy = ', abs((I - true_val)/true_val*100))
# Out:
# a)
# I = 1.5691342555492505
# accuracy =  0.10581074180619238
# b)
# N = 819200
# I = 1.570796324551848
# accuracy =  1.427969111881128e-07
# N = 26214400
# I = 1.570796326782606
# accuracy =  7.824447232371936e-10
